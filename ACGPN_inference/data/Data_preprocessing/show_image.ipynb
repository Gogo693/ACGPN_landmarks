# %%
from PIL import Image, ImageDraw
import os
import cv2

# %%
dirlist = ['test_color',  'test_colormask',  'test_edge',  'test_img',  'test_label',  'test_mask']  #,'test_pose']

for direc in dirlist:
    name = os.listdir(direc)[1]
    print(name)
    img = Image.open(direc + '/' + name)
    display(img)
    #img = cv2.imread('g4g.png') 
    #cv2.imshow('image', img)
# Out:
# 014114_1.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F0422B32F70>
# 06221_test.png
# <PIL.PngImagePlugin.PngImageFile image mode=1 size=512x512 at 0x7F0422B32A60>
# 014114_1.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=192x256 at 0x7F0422B329A0>
# 011623_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F0422B32C70>
# 012934_0.png
# <PIL.PngImagePlugin.PngImageFile image mode=L size=192x256 at 0x7F0422B32F70>
# 04374.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x7F03DB8CA9A0>

# %%
direc = '../../results/'
display(img)
i = 0

for img in os.listdir(direc):
    name = direc + img
    print(name)
    img = Image.open(name)
    display(img)
    i += 1
    if i == 10:
        break
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DFC70>
# ../../results/016812_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DFC70>
# ../../results/011623_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8EF100>
# ../../results/018807_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DFC70>
# ../../results/011850_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DF9D0>
# ../../results/004620_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8EF310>
# ../../results/003032_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DF460>
# ../../results/010261_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DF460>
# ../../results/012975_0.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F03DB8DFC70>
# ...

# %%
img = Image.open('../../results/000010_0.jpg')
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=192x256 at 0x7F0422B32D60>
